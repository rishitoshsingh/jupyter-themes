# %%
# !jt -l
# Out:
# Available Themes:
#    chesterish
#    grade3
#    gruvboxd
#    gruvboxl
#    monokai
#    oceans16
#    onedork
#    solarizedd
#    solarizedl

# %%
# !jt -t oceans16 -N -f roboto -fs 10 -cellw 60% -cursc r -tf roboto -tfs 10 -nf ptsans -nfs 13

# %%
# !jt -t onedork -fs 95 -altp -tfs 11 -nfs 115 -cellw 88% -T

# %%
# !jt -t grade3 -fs 95 -altp -tfs 11 -nfs 115 -cellw 88% -T

# %%
# !jt -r
# Out:
# Reset css and font defaults in:
# /home/rishi/.jupyter/custom &
# /home/rishi/.local/share/jupyter/nbextensions

# %%
from jupyterthemes import jtplot

# choose which theme to inherit plotting style from
# onedork | grade3 | oceans16 | chesterish | monokai | solarizedl | solarizedd
# jtplot.style(theme='grade3')
jtplot.style()
plt.hist([1,1,1,1,3,3,3,4,5,5,5,6,6,7,7,8,9,9,9,6,5,4,3,4,5,5,6,6,7,7])
plt.show()

from matplotlib import pyplot as plt
# %matplotlib inline
plt.plot([1,2,3],[4,5,1])

#Showing what we plotted
plt.show()
